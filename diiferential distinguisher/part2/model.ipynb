# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score


results = []

for i in range(1,7):
    print(f"Running Round {i} ........")

    df = pd.read_csv(f"datasets/ASCON_differential_round_{i}.csv")
    print(df.shape)

    x = df.drop(columns = ["label"])
    y = df["label"]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

    model = XGBClassifier(
    n_estimators = 200,
    random_state = 0)

    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    y_prob = model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_prob)

    results.append({
        "Rounds" : i,
        "Accuracy" : acc,
        "F1 Score" : f1,
        "ROC AUC Curve" : auc
    })

print("All rounds run successfully !!!")

    # print(f"Accuracy score = {acc : .4f}")
    # print(f"F1 Score = {f1 : .4f}")
    # print(f"ROC AUC SCORE = {auc : .4f}")
    # print()
# Out:
# Running Round 1 ........
# (20000, 321)
# Running Round 2 ........
# (20000, 321)
# Running Round 3 ........
# (20000, 321)
# Running Round 4 ........
# (20000, 321)
# Running Round 5 ........
# (20000, 321)
# Running Round 6 ........
# (20000, 321)
# All rounds run successfully !!!

# %%
res_df = pd.DataFrame(results)
print(res_df)
# Out:
#    Rounds  Accuracy  F1 Score  ROC AUC Curve
# 0       1    1.0000  1.000000       1.000000
# 1       2    1.0000  1.000000       1.000000
# 2       3    0.9995  0.999506       1.000000
# 3       4    0.5060  0.502518       0.506491
# 4       5    0.5065  0.512593       0.507466
# 5       6    0.5005  0.497232       0.493853
